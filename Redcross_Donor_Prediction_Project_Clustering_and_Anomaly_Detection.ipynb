# %% [markdown]
# <a href="https://colab.research.google.com/github/tubameric/DFW-Redcross-Project/blob/main/Redcross_Donor_Prediction_Project_Clustering_and_Anomaly_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install pycaret
# !pip install -U --pre pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.0/258.0 kB 25.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.7/80.7 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 40.8 MB/s eta 0:00:00
# ...

# %%
# Importing data from the webserver
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/tubameric/PortfolioProjects/main/Donor%20Dataset%20-%202023%20-%20Sheet1.csv')

data.shape
# Out:
# (34508, 23)

# %%
# Displaying the data columns
data.columns
# Out:
# Index(['DonorUniqueId', 'DonorPostalCode', 'DonorAge', 'MaritalStatus',
#        'GenderIdentity', 'IsMemberFlag', 'IsAlumnusFlag', 'IsParentFlag',
#        'HasInvolvementFlag', 'WealthRating', 'AcademicDegreeLevel',
#        'PreferredAddressType', 'HasEmailFlag', 'ConsecutiveDonorYears',
#        'LastFiscalYearDonation', 'Donation2FiscalYearsAgo',
#        'Donation3FiscalYearsAgo', 'Donation4FiscalYearsAgo',
#        'Donation5FiscalYearsAgo', 'CurrentFiscalYearDonation',
#        'CumulativeDonationAmount', 'DonorDateOfBirth', 'DonorIndicatorFlag.'],
#       dtype='object')

# %%
# Importing anomaly detection algos from pycaret
from pycaret.anomaly import *

# %%
# Setting up the pycaret anomaly detection algo configuration
anomaly_setup = setup(data)
# Out:
# <style type="text/css">
# #T_9df99_row6_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9df99" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9df99_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9df99_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9df99_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9df99_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9df99_row0_col1" class="data row0 col1" >3061</td>
#     </tr>
#     <tr>
#       <th id="T_9df99_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9df99_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_9df99_row1_col1" class="data row1 col1" >(34508, 23)</td>
#     </tr>
#     <tr>
# ...

# %%
# Building an anomaly detection model using knn algo
knn_model = create_model('knn')
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
# Identifying/predicting the anomalies using the knn model
knn_anomalies= predict_model(knn_model,data)

# %%
# Exporting the anomaly scores file to a csv
knn_anomalies.to_csv("DFW Redcross Donor Anomalies.csv")

# %%
# Listing the anomalies
data_anomalies = knn_anomalies[knn_anomalies['Anomaly']==1]
data_anomalies.shape
data_anomalies
# Out:
#        DonorUniqueId  DonorPostalCode  DonorAge  MaritalStatus_Married  \
# 1                2.0          77643.0      33.0                    1.0
# 42              43.0           1546.0      42.0                    1.0
# 60              61.0          76306.0      42.0                    1.0
# 71              72.0          47708.0      83.0                    1.0
# 74              75.0          74766.0      42.0                    0.0
# ...              ...              ...       ...                    ...
# 34360        34361.0          15066.0      42.0                    1.0
# 34459        34460.0          15901.0      42.0                    1.0
# 34463        34464.0          39069.0      34.0                    1.0
# 34484        34485.0          32092.0      42.0                    1.0
# 34497        34498.0          52644.0      25.0                    1.0
#
#        MaritalStatus_Single  MaritalStatus_Separated  MaritalStatus_Widowed  \
# ...

# %%
# Assigning the non-anomalies to a clean dataset
clean_no_anomalies = knn_anomalies[knn_anomalies['Anomaly']==0]

clean_no_anomalies.shape
# Out:
# (32854, 4861)

# %%
# Importing clustering algorithms
from pycaret.clustering import *

# %%
# Setting up the pycaret anomaly detection algo configuration
cluster_setup =setup(clean_no_anomalies,session_id=123)
# Out:
# <style type="text/css">
# #T_b179e_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b179e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b179e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b179e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b179e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b179e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b179e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b179e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b179e_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_b179e_row1_col1" class="data row1 col1" >(32854, 4861)</td>
#     </tr>
#     <tr>
# ...

# %%
# Building a clustering model using kmeans algo
kmeans_model = create_model('kmeans')
# Out:
# <style type="text/css">
# </style>
# <table id="T_78ae4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78ae4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_78ae4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_78ae4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_78ae4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_78ae4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_78ae4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78ae4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78ae4_row0_col0" class="data row0 col0" >0.4161</td>
#       <td id="T_78ae4_row0_col1" class="data row0 col1" >61994.2959</td>
# ...

# %%
# Identifying/predicting the clusters using the kmeans algo
kmeans_data = assign_model(kmeans_model)

# %%
# Displaying the data with clusters
kmeans_data

# Exporting to a csv file
kmeans_data.to_csv("DFW Redcross Donor Data Clusters.csv")

# %%
# Displaying the number of clusters and the count of assigned data points
kmeans_data['Cluster'].value_counts()
# Out:
# Cluster
# Cluster 2    9906
# Cluster 0    9289
# Cluster 3    6834
# Cluster 1    6825
# Name: count, dtype: int64
